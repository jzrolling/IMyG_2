# %%
cd ~/PycharmProjects/IMyG_2/
# Out:
# /Users/jz-rolling/PycharmProjects/IMyG_2

# %%
import IMyG as im
import tifffile
import numpy as np
import pandas as pd
import glob

# %%
folders = glob.glob("/Users/jz-rolling/Downloads/20191105/")
for folder in folders:
    header = folder.split("/")[-2]
    #im.IO.read_from_folder(folder,folder,header)
    im.IO.create_metrics_folder(folder,folder,header+"_0","CFP",all_cells=True,re_align = False,max_th=0,project=False)
# Out:
# 770 cells accounted

# %%
im.IO.create_metrics_folder("/Users/jz-rolling/Downloads/FtsZ_mneongreen_images/FTSZ_DAPI/","ftsZ_dapi3","FITC_CLD",all_cells=True,re_align = True,max_th=0)

# %%
import pandas as pd
import numpy as np
import tifffile
from skimage.feature import peak_local_max
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("/Users/jz-rolling/Downloads/rpsJ-positive-eGFP/output/rpsJ_FITC_summary_normalized.xls")

# %%
data = np.load("/Users/jz-rolling/Downloads/rpsJ-positive-eGFP/output/rpsJ_FITC_padded_demograph.npy")

# %%
args = df.sort_values(by="Length [um]")
m = args[args["Cell"] == 0]

# %%
tifffile.imshow(data[m.index])
# Out:
# (<Figure size 988.8x604.8 with 2 Axes>,
# ...
#  <matplotlib.image.AxesImage at 0x133b72438>)

# %%
m = im.IO.pk.load(open("/Volumes/Sam/MSR9_IDW/plate9_raw_files/08272019_raw_files/output/Well_B07/MSR9_B07_0_sample_0_cells.pk","rb"))

# %%
m[227].plot_advanced()

# %%
n=56
data = m[n].fl_img["FITC"]

# %%
ndata = im.helper_func.straighten_cell_normalize_width(data,m[n].width,m[n].midline,pad=1,remove_cap=0)

# %%
tifffile.imshow(im.helper_func.filters.gaussian(ndata,sigma=1))
# Out:
# (<Figure size 988.8x604.8 with 2 Axes>,
# ...
#  <matplotlib.image.AxesImage at 0x132a3ca90>)

# %%
coordinates = peak_local_max(ndata,min_distance=3)

# %%
fig = plt.figure(figsize=(5,5))
plt.imshow(ndata)
plt.scatter(coordinates.T[1],coordinates.T[0],c='r')

# %%
for i in range(1,5):
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
np.percentile([1,2,3,4,5],2)
# Out:
# 1.08
